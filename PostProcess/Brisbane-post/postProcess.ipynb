# %%
import pandas as pd
import os
import sys
df = pd.DataFrame()
listFiles = os.listdir()
for fileName in listFiles:
    if fileName.endswith('.json'):
        try:
            df_temp = pd.read_json(fileName, lines=True)
        except:
            df_temp = pd.read_json(fileName)
        df = pd.concat([df, df_temp], ignore_index=True)
df.sort_values(by=['avg_val_loss', 'avg_train_loss'], ascending=True, inplace=True)
df
# Out:
#                        model  hidden_dim  heads               units  \
# 1531      GAT_3GCN_3FFNN_elu          64      4  [1024, 1024, 1024]
# 701       GAT_2GCN_3FFNN_elu          32      8  [1024, 1024, 1024]
# 1532      GAT_3GCN_3FFNN_elu          64      4   [1024, 1024, 512]
# 1448      GAT_3GCN_3FFNN_elu          32      8  [1024, 1024, 1024]
# 1533      GAT_3GCN_3FFNN_elu          64      4   [1024, 1024, 256]
# ...                      ...         ...    ...                 ...
# 897   GAT_2GCN_3FFNN_sigmoid          32      4        [32, 16, 16]
# 1609  GAT_1GCN_3FFNN_sigmoid          32      4        [32, 16, 16]
# 896   GAT_2GCN_3FFNN_sigmoid          32      4        [32, 32, 16]
# 8     GAT_3GCN_3FFNN_sigmoid          32      4        [64, 16, 16]
# 1775  GAT_1GCN_3FFNN_sigmoid          64      4        [32, 16, 16]
#
#       avg_val_loss  avg_train_loss
# 1531      0.006815        0.005598
# 701       0.006888        0.005601
# 1532      0.006921        0.005642
# 1448      0.006974        0.005426
# 1533      0.007079        0.005767
# ...            ...             ...
# 897       0.012869        0.012227
# 1609      0.012900        0.012254
# 896       0.012933        0.012186
# 8         0.013059        0.011933
# 1775      0.013335        0.012087
#
# [1939 rows x 6 columns]
