# %%
import pandas as pd
import os
import sys
df = pd.DataFrame()
listFiles = os.listdir()
for fileName in listFiles:
    if fileName.endswith('.json'):
        try:
            df_temp = pd.read_json(fileName, lines=True)
        except:
            df_temp = pd.read_json(fileName)
        df = pd.concat([df, df_temp], ignore_index=True)
df.sort_values(by=['avg_val_loss', 'avg_train_loss'], ascending=True, inplace=True)
df
# Out:
#                        model  hidden_dim  heads               units  \
# 1413      GAT_3GCN_3FFNN_elu          32      8  [1024, 1024, 1024]
# 860       GAT_2GCN_3FFNN_elu          64      4  [1024, 1024, 1024]
# 777       GAT_2GCN_3FFNN_elu          32      8  [1024, 1024, 1024]
# 1496      GAT_3GCN_3FFNN_elu          64      4  [1024, 1024, 1024]
# 922       GAT_2GCN_3FFNN_elu          64      8     [512, 512, 512]
# ...                      ...         ...    ...                 ...
# 951   GAT_2GCN_3FFNN_sigmoid          32      4        [64, 16, 16]
# 1     GAT_3GCN_3FFNN_sigmoid          32      4        [32, 32, 16]
# 1507  GAT_1GCN_3FFNN_sigmoid          32      4        [32, 16, 16]
# 2     GAT_3GCN_3FFNN_sigmoid          32      4        [32, 16, 16]
# 657       GAT_2GCN_3FFNN_elu          32      4       [128, 16, 16]
#
#       avg_val_loss  avg_train_loss
# 1413      0.010086        0.007631
# 860       0.010110        0.007758
# 777       0.010141        0.007725
# 1496      0.010270        0.008387
# 922       0.010292        0.008017
# ...            ...             ...
# 951       0.017617        0.016227
# 1         0.017685        0.016082
# 1507      0.017774        0.016690
# 2         0.018339        0.016901
# 657       0.018501        0.017078
#
# [1837 rows x 6 columns]
